# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('cardekho_imputated.csv',index_col=0)

# %%
df.head()
# Out:
#         car_name    brand     model  vehicle_age  km_driven seller_type  \
# 0    Maruti Alto   Maruti      Alto            9     120000  Individual
# 1  Hyundai Grand  Hyundai     Grand            5      20000  Individual
# 2    Hyundai i20  Hyundai       i20           11      60000  Individual
# 3    Maruti Alto   Maruti      Alto            9      37000  Individual
# 4  Ford Ecosport     Ford  Ecosport            6      30000      Dealer
#
#   fuel_type transmission_type  mileage  engine  max_power  seats  \
# 0    Petrol            Manual    19.70     796      46.30      5
# 1    Petrol            Manual    18.90    1197      82.00      5
# 2    Petrol            Manual    17.00    1197      80.00      5
# 3    Petrol            Manual    20.92     998      67.10      5
# 4    Diesel            Manual    22.77    1498      98.59      5
#
#    selling_price
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000

# %% [markdown]
# #### Feature Engineering

# %%
df.isnull().sum()
# Out:
# car_name             0
# brand                0
# model                0
# vehicle_age          0
# km_driven            0
# seller_type          0
# fuel_type            0
# transmission_type    0
# mileage              0
# engine               0
# max_power            0
# seats                0
# selling_price        0
# dtype: int64

# %%
df.drop(columns=['brand','car_name'],inplace=True)
df.head()
# Out:
#       model  vehicle_age  km_driven seller_type fuel_type transmission_type  \
# 0      Alto            9     120000  Individual    Petrol            Manual
# 1     Grand            5      20000  Individual    Petrol            Manual
# 2       i20           11      60000  Individual    Petrol            Manual
# 3      Alto            9      37000  Individual    Petrol            Manual
# 4  Ecosport            6      30000      Dealer    Diesel            Manual
#
#    mileage  engine  max_power  seats  selling_price
# 0    19.70     796      46.30      5         120000
# 1    18.90    1197      82.00      5         550000
# 2    17.00    1197      80.00      5         215000
# 3    20.92     998      67.10      5         226000
# 4    22.77    1498      98.59      5         570000

# %%
X=df.drop('selling_price',axis=1)
y=df['selling_price']

# %%
df['model'].value_counts()
# Out:
# model
# i20            906
# Swift Dzire    890
# Swift          781
# Alto           778
# City           757
#               ...
# Ghibli           1
# Altroz           1
# GTC4Lusso        1
# Aura             1
# Gurkha           1
# Name: count, Length: 120, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
X['model']=le.fit_transform(X['model'])

# %%
num_feature=X.select_dtypes(exclude='object').columns
cat_feature=X.select_dtypes(include='object').columns
onehot_features=[feature for feature in cat_feature if X[feature].nunique()<=10]
LabelEncoder_features=[feature for feature in cat_feature if X[feature].nunique()>10]
print(num_feature)
print(onehot_features)
print(LabelEncoder_features)
# Out:
# Index(['model', 'vehicle_age', 'km_driven', 'mileage', 'engine', 'max_power',
#        'seats'],
#       dtype='object')
# ['seller_type', 'fuel_type', 'transmission_type']
# []

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import ColumnTransformer

ohe=OneHotEncoder(drop='first')
std_scaler=StandardScaler()
preprocessor=ColumnTransformer(
    transformers=[
        ('onehot',ohe,onehot_features),
        ('scaler',std_scaler,num_feature)
    ],remainder='passthrough'
)

# %%
X=preprocessor.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=43)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
def evaluate_model(true,pred):
    mae=mean_absolute_error(true,pred)
    mse=mean_squared_error(true,pred)
    rmse=np.sqrt(mse)
    r2=r2_score(true,pred)
    return mae,mse,rmse,r2

# %%
models={
    'RandomForest':RandomForestRegressor(),
    'LinearRegression':LinearRegression(),
    'Ridge':Ridge(),
    'Lasso':Lasso(),
    'DecisionTree':DecisionTreeRegressor(),
    'KNeighbors':KNeighborsRegressor()
}

for i in range(len(models)):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    y_train_pred=model.predict(X_train)
    y_test_pred=model.predict(X_test)
    mae_train,mse_train,rmse_train,r2_train=evaluate_model(y_train,y_train_pred)
    mae_test,mse_test,rmse_test,r2_test=evaluate_model(y_test,y_test_pred)
    print(f"{list(models.keys())[i]} Results:")
    print(f"Train MAE: {mae_train}, MSE: {mse_train}, RMSE: {rmse_train}, R2: {r2_train}")
    print('----------------------------------')
    print(f"Test MAE: {mae_test}, MSE: {mse_test}, RMSE: {rmse_test}, R2: {r2_test}")   
    print('--------------------------------------------------------------------------')
# Out:
# RandomForest Results:
# Train MAE: 39024.410135373044, MSE: 11727874633.10331, RMSE: 108295.31214740235, R2: 0.9848256709655601
# ----------------------------------
# Test MAE: 100413.3770548207, MSE: 96964748507.52708, RMSE: 311391.63204480475, R2: 0.8929193150587623
# --------------------------------------------------------------------------
# LinearRegression Results:
# Train MAE: 265287.33444572956, MSE: 288921093492.94214, RMSE: 537513.8077230594, R2: 0.62617406181362
# ----------------------------------
# Test MAE: 269560.96072889527, MSE: 325279362843.6122, RMSE: 570332.6773415777, R2: 0.6407855689138456
# --------------------------------------------------------------------------
# Ridge Results:
# Train MAE: 265253.2112325706, MSE: 288921380074.72345, RMSE: 537514.0743038488, R2: 0.6261736910144444
# ----------------------------------
# Test MAE: 269536.4101263026, MSE: 325285660058.4738, RMSE: 570338.1979654473, R2: 0.6407786147362606
# --------------------------------------------------------------------------
# Lasso Results:
# Train MAE: 265285.8718082063, MSE: 288921098415.22424, RMSE: 537513.8123018089, R2: 0.6261740554448336
# ----------------------------------
# Test MAE: 269561.05725160835, MSE: 325281198565.02454, RMSE: 570334.2866819638, R2: 0.6407835416791111
# --------------------------------------------------------------------------
# DecisionTree Results:
# Train MAE: 4815.493186242699, MSE: 394009677.1576898, RMSE: 19849.677003863057, R2: 0.9994902032404859
# ----------------------------------
# Test MAE: 125118.3911774246, MSE: 113349076337.80228, RMSE: 336673.5456459302, R2: 0.8748256771813696
# --------------------------------------------------------------------------
# KNeighbors Results:
# Train MAE: 89614.02092796886, MSE: 92519636788.00291, RMSE: 304170.4074823896, R2: 0.8802917446947044
# ----------------------------------
# Test MAE: 114323.45118391178, MSE: 123147831852.09212, RMSE: 350924.2537244927, R2: 0.8640046574995577
# --------------------------------------------------------------------------

# %%
knn_params={
    'n_neighbors':[3,5,7,9,11]
}
rf_params={   
    'n_estimators':[100,200,300],
    'max_depth':[None,10,20,30],
    'min_samples_split':[2,5,10,15],
    'max_features':[5,7,'auto',8]
}

# %%
randomcv_models=[
    ('KNN',KNeighborsRegressor(),knn_params),
    ('RF',RandomForestRegressor(),rf_params)
]
from sklearn.model_selection import RandomizedSearchCV
for name,model,params in randomcv_models:
    print(f"Tuning hyperparameters for {name}")
    random_search=RandomizedSearchCV(estimator=model,
                                     param_distributions=params,
                                     n_iter=100,
                                     scoring='neg_mean_squared_error',
                                     cv=5,
                                     verbose=2,
                                     n_jobs=-1,
                                     random_state=43)
    random_search.fit(X_train,y_train)
    print(f"Best parameters for {name}: {random_search.best_params_}")
    best_model=random_search.best_estimator_
    y_test_pred=best_model.predict(X_test)
    mae_test,mse_test,rmse_test,r2_test=evaluate_model(y_test,y_test_pred)
    print(f"Test MAE: {mae_test}, MSE: {mse_test}, RMSE: {rmse_test}, R2: {r2_test}")   
    print('--------------------------------------------------------------------------')
# Out:
# Tuning hyperparameters for KNN
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=3; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.0s
# [CV] END ......................................n_neighbors=5; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.1s
# [CV] END ......................................n_neighbors=7; total time=   0.0s
# [CV] END ......................................n_neighbors=9; total time=   0.0s
# [CV] END ......................................n_neighbors=9; total time=   0.0s
# [CV] END ......................................n_neighbors=9; total time=   0.0s
# [CV] END ......................................n_neighbors=9; total time=   0.0s
# [CV] END ......................................n_neighbors=9; total time=   0.0s
# [CV] END .....................................n_neighbors=11; total time=   0.0s
# [CV] END .....................................n_neighbors=11; total time=   0.0s
# [CV] END .....................................n_neighbors=11; total time=   0.0s
# [CV] END .....................................n_neighbors=11; total time=   0.0s
# [CV] END .....................................n_neighbors=11; total time=   0.0s
# Best parameters for KNN: {'n_neighbors': 3}
# Test MAE: 116919.66699102605, MSE: 189020772479.9077, RMSE: 434765.19235089154, R2: 0.7912594618476305
# --------------------------------------------------------------------------
# Tuning hyperparameters for RF
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END max_depth=20, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.4s
# [CV] END max_depth=20, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=20, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=20, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.1s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.2s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=None, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=30, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.4s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=300; total time=   2.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=2, n_estimators=300; total time=   2.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=30, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=30, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=30, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=300; total time=   3.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.6s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.6s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.4s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.4s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.5s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.5s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=300; total time=   2.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.4s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.7s
# [CV] END max_depth=10, max_features=8, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=5, n_estimators=300; total time=   1.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.8s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.8s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=10, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=30, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=15, n_estimators=100; total time=   1.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=10, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.1s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.1s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.1s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.4s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.5s
# [CV] END max_depth=20, max_features=5, min_samples_split=5, n_estimators=200; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=300; total time=   1.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=10, n_estimators=300; total time=   1.6s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.5s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=15, n_estimators=100; total time=   0.5s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=200; total time=   1.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.8s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.3s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.4s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=15, n_estimators=200; total time=   0.0s
# [CV] END max_depth=10, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=30, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=30, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.9s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.9s
# [CV] END max_depth=30, max_features=8, min_samples_split=2, n_estimators=300; total time=   3.6s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.8s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.9s
# [CV] END max_depth=10, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END max_depth=30, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=200; total time=   2.1s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=200; total time=   2.2s
# [CV] END max_depth=10, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.6s
# [CV] END max_depth=30, max_features=5, min_samples_split=2, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END max_depth=20, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.6s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.7s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.7s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.1s
# [CV] END max_depth=20, max_features=7, min_samples_split=2, n_estimators=200; total time=   2.2s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.6s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=5, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=200; total time=   1.5s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.5s
# [CV] END max_depth=10, max_features=5, min_samples_split=2, n_estimators=300; total time=   1.5s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.7s
# [CV] END max_depth=10, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.4s
# [CV] END max_depth=10, max_features=5, min_samples_split=5, n_estimators=300; total time=   1.5s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.2s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.6s
# [CV] END max_depth=30, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.8s
# [CV] END max_depth=30, max_features=8, min_samples_split=15, n_estimators=300; total time=   2.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.6s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.8s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.8s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=7, min_samples_split=10, n_estimators=300; total time=   2.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.3s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.4s
# [CV] END max_depth=10, max_features=8, min_samples_split=10, n_estimators=300; total time=   2.3s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=10, max_features=auto, min_samples_split=2, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=10, n_estimators=100; total time=   0.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=20, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=20, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=20, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=20, max_features=5, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=300; total time=   1.9s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=30, max_features=5, min_samples_split=15, n_estimators=300; total time=   2.0s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.0s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.8s
# [CV] END max_depth=30, max_features=8, min_samples_split=5, n_estimators=100; total time=   1.1s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=30, max_features=auto, min_samples_split=2, n_estimators=300; total time=   0.0s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=5, min_samples_split=2, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=None, max_features=7, min_samples_split=10, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.8s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=300; total time=   2.2s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=300; total time=   2.3s
# [CV] END max_depth=10, max_features=8, min_samples_split=2, n_estimators=300; total time=   2.3s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
# [CV] END max_depth=20, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s[CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=100; total time=   0.9s
#
# [CV] END max_depth=20, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=auto, min_samples_split=5, n_estimators=200; total time=   0.0s
# [CV] END max_depth=30, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=30, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=None, max_features=auto, min_samples_split=2, n_estimators=200; total time=   0.0s
# [CV] END max_depth=20, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=20, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=20, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=30, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.1s
# [CV] END max_depth=20, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=30, max_features=7, min_samples_split=2, n_estimators=100; total time=   1.2s
# [CV] END max_depth=20, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.9s
# [CV] END max_depth=20, max_features=8, min_samples_split=15, n_estimators=200; total time=   1.8s
# [CV] END max_depth=20, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=20, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=20, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=20, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.2s
# [CV] END max_depth=20, max_features=8, min_samples_split=5, n_estimators=300; total time=   3.3s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.2s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=200; total time=   2.0s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=20, max_features=8, min_samples_split=2, n_estimators=200; total time=   2.5s
# [CV] END max_depth=None, max_features=8, min_samples_split=10, n_estimators=200; total time=   1.9s
# [CV] END max_depth=30, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.8s
# [CV] END max_depth=30, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.7s
# [CV] END max_depth=30, max_features=7, min_samples_split=5, n_estimators=300; total time=   2.5s
# Best parameters for RF: {'n_estimators': 300, 'min_samples_split': 2, 'max_features': 8, 'max_depth': 30}
# Test MAE: 98382.7589452, MSE: 93141348395.09297, RMSE: 305190.6754720612, R2: 0.8971415948990701
# --------------------------------------------------------------------------

# %%
models={
    'RandomForest':RandomForestRegressor(n_estimators= 300, min_samples_split= 2, max_features= 8, max_depth= 20),
    'KNeighbors':KNeighborsRegressor(n_neighbors=3)
}
for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)
    y_train_pred=model.predict(X_train)
    y_test_pred=model.predict(X_test)
    mae_train,mse_train,rmse_train,r2_train=evaluate_model(y_train,y_train_pred)
    mae_test,mse_test,rmse_test,r2_test=evaluate_model(y_test,y_test_pred)
    print(f"{list(models.keys())[i]} Results After Hyperparameter Tuning:")
    print(f"Train MAE: {mae_train}, MSE: {mse_train}, RMSE: {rmse_train}, R2: {r2_train}")
    print('----------------------------------')
    print(f"Test MAE: {mae_test}, MSE: {mse_test}, RMSE: {rmse_test}, R2: {r2_test}")   
    print('--------------------------------------------------------------------------')
# Out:
# RandomForest Results After Hyperparameter Tuning:
# Train MAE: 40942.37506383795, MSE: 14910294908.001665, RMSE: 122107.71846202707, R2: 0.9807080372179351
# ----------------------------------
# Test MAE: 97549.98253991798, MSE: 87288301218.93607, RMSE: 295445.9362031166, R2: 0.9036052665969099
# --------------------------------------------------------------------------
# KNeighbors Results After Hyperparameter Tuning:
# Train MAE: 76615.7324789098, MSE: 56772712664.87986, RMSE: 238270.251321645, R2: 0.926543568284491
# ----------------------------------
# Test MAE: 116919.66699102605, MSE: 189020772479.9077, RMSE: 434765.19235089154, R2: 0.7912594618476305
# --------------------------------------------------------------------------
