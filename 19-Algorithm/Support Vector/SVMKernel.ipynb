# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
x=np.linspace(-5.0, 5.0, 100)
y=np.sqrt(10**2 - x**2)
y=np.hstack((y, -y))
x=np.hstack((x, x))

# %%
x1=np.linspace(-5.0, 5.0, 100)
y1=np.sqrt(5**2 - x1**2)
y1=np.hstack((y1, -y1))
x1=np.hstack((x1, x1))

# %%
plt.scatter(x, y)
plt.scatter(x1, y1)

# %%
df1=pd.DataFrame(np.vstack((y, x)).T, columns=['X1', 'X2'])
df1['Y']=0
df2=pd.DataFrame(np.vstack((y1, x1)).T, columns=['X1', 'X2'])
df2['Y']=1
df = pd.concat([df1, df2], ignore_index=True)
df.head(5)
# Out:
#          X1       X2  Y
# 0  8.660254 -5.00000  0
# 1  8.717792 -4.89899  0
# 2  8.773790 -4.79798  0
# 3  8.828277 -4.69697  0
# 4  8.881281 -4.59596  0

# %%
X=df.iloc[:,:2]
y=df['Y']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
df['X1_Square']=df['X1']**2
df['X2_Square']=df['X2']**2
df['X1*X2']=df['X1']*df['X2']
df.head(5)
# Out:
#          X1       X2  Y  X1_Square  X2_Square      X1*X2
# 0  8.660254 -5.00000  0  75.000000  25.000000 -43.301270
# 1  8.717792 -4.89899  0  75.999898  24.000102 -42.708375
# 2  8.773790 -4.79798  0  76.979390  23.020610 -42.096467
# 3  8.828277 -4.69697  0  77.938476  22.061524 -41.466150
# 4  8.881281 -4.59596  0  78.877155  21.122845 -40.818009

# %%
X=df.iloc[:,:5]
y=df['Y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# !pip install plotly
# !pip install --upgrade nbformat
# !pip install --upgrade notebook
# Out:
# Requirement already satisfied: plotly in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (6.5.0)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from plotly) (2.10.0)
# Requirement already satisfied: packaging in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from plotly) (25.0)
# Requirement already satisfied: nbformat in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (5.10.4)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbformat) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=2.6->nbformat) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.3.8)
# Collecting notebook
#   Downloading notebook-7.5.0-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-server<3,>=2.4.0 (from notebook)
#   Downloading jupyter_server-2.17.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab-server<3,>=2.28.0 (from notebook)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyterlab<4.6,>=4.5.0rc0 (from notebook)
#   Downloading jupyterlab-4.5.0-py3-none-any.whl.metadata (16 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: tornado>=6.2.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from notebook) (6.5.2)
# Collecting anyio>=3.1.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi-25.1.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: packaging>=22.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.0)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading prometheus_client-0.23.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: pyzmq>=24 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.0.2)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: traitlets>=5.6.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Collecting httpx<1,>=0.25.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyterlab<4.6,>=4.5.0rc0->notebook) (6.30.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting setuptools>=41.1.0 (from jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: certifi in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (2025.10.5)
# Collecting httpcore==1.* (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.6,>=4.5.0rc0->notebook)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->notebook)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.25.1)
# Requirement already satisfied: requests>=2.31 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Collecting sniffio>=1.1 (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.4 kB)
# Requirement already satisfied: appnope>=0.1.2 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (9.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (7.0.0)
# Requirement already satisfied: decorator in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (2.19.2)
# Requirement already satisfied: stack_data in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.28.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.3.8)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading python_json_logger-4.0.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pyyaml>=5.3 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting rfc3987-syntax>=1.1.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading rfc3987_syntax-1.1.0-py3-none-any.whl.metadata (7.7 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webcolors-25.10.0-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: beautifulsoup4 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.14.2)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting defusedxml (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting mistune<4,>=2.0.3 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading mistune-3.1.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting nbclient>=0.5.0 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting webencodings (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.5.0)
# Collecting lark>=1.2.2 (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading lark-1.3.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting cffi>=1.0.1 (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Requirement already satisfied: soupsieve>1.2 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Collecting arrow>=0.15.0 (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook)
#   Downloading arrow-1.4.0-py3-none-any.whl.metadata (7.7 kB)
# Requirement already satisfied: tzdata in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/jay.khandelwal/Documents/Personal/Python/myenv/lib/python3.13/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.6,>=4.5.0rc0->notebook) (0.2.3)
# Downloading notebook-7.5.0-py3-none-any.whl (14.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 39.4 MB/s  0:00:00 eta 0:00:01
# Downloading jupyter_server-2.17.0-py3-none-any.whl (388 kB)
# Downloading jupyterlab-4.5.0-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 50.2 MB/s  0:00:00 eta 0:00:01
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading anyio-4.11.0-py3-none-any.whl (109 kB)
# Downloading argon2_cffi-25.1.0-py3-none-any.whl (14 kB)
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 50.5 MB/s  0:00:00m0:00:01
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Using cached jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading mistune-3.1.4-py3-none-any.whl (53 kB)
# Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading prometheus_client-0.23.1-py3-none-any.whl (61 kB)
# Downloading python_json_logger-4.0.0-py3-none-any.whl (15 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-macosx_11_0_arm64.whl (173 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading rfc3987_syntax-1.1.0-py3-none-any.whl (8.0 kB)
# Downloading lark-1.3.1-py3-none-any.whl (113 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading webcolors-25.10.0-py3-none-any.whl (14 kB)
# Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading argon2_cffi_bindings-25.1.0-cp39-abi3-macosx_11_0_arm64.whl (31 kB)
# Using cached cffi-2.0.0-cp313-cp313-macosx_11_0_arm64.whl (181 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading arrow-1.4.0-py3-none-any.whl (68 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, websocket-client, webcolors, uri-template, tinycss2, terminado, sniffio, setuptools, send2trash, rfc3986-validator, rfc3339-validator, pyyaml, python-json-logger, pycparser, prometheus-client, pandocfilters, mistune, lark, jupyterlab-pygments, jsonpointer, json5, h11, fqdn, defusedxml, bleach, babel, async-lru, rfc3987-syntax, jupyter-server-terminals, httpcore, cffi, arrow, anyio, isoduration, httpx, argon2-cffi-bindings, argon2-cffi, nbclient, jupyter-events, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46/46 [notebook]notebook]jupyterlab]]er]terminals]
# Successfully installed anyio-4.11.0 argon2-cffi-25.1.0 argon2-cffi-bindings-25.1.0 arrow-1.4.0 async-lru-2.0.5 babel-2.17.0 bleach-6.3.0 cffi-2.0.0 defusedxml-0.7.1 fqdn-1.5.1 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 isoduration-20.11.0 json5-0.12.1 jsonpointer-3.0.0 jupyter-events-0.12.0 jupyter-lsp-2.3.0 jupyter-server-2.17.0 jupyter-server-terminals-0.5.3 jupyterlab-4.5.0 jupyterlab-pygments-0.3.0 jupyterlab-server-2.28.0 lark-1.3.1 mistune-3.1.4 nbclient-0.10.2 nbconvert-7.16.6 notebook-7.5.0 notebook-shim-0.2.4 pandocfilters-1.5.1 prometheus-client-0.23.1 pycparser-2.23 python-json-logger-4.0.0 pyyaml-6.0.3 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 rfc3987-syntax-1.1.0 send2trash-1.8.3 setuptools-80.9.0 sniffio-1.3.1 terminado-0.18.1 tinycss2-1.4.0 uri-template-1.3.0 webcolors-25.10.0 webencodings-0.5.1 websocket-client-1.9.0

# %%
import plotly.express as px
px.scatter_3d(df, x='X1', y='X2', z='X1*X2', color='Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'X1=%{x}<br>X2=%{y}<br>X1*X2=%{z}<br>Y=%{marker.color}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                                    'dtype': 'i1'},
#                          'coloraxis': 'coloraxis',
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'scene': 'scene',
#               'showlegend': False,
#               'type': 'scatter3d',
#               'x': {'bdata': ('6y830QxSIUBFUglwgm8hQOSR0jEujC' ... 'LdsYL2v/sYuQKV/++/AAAAAAAAAIA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAFMBDYt7OkJgTwIbEvJ0hMR' ... 'ydITETQERi3s6QmBNAAAAAAAAAFEA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('5vuEBZCmRcA8YDcJrFpFwNB0wAZZDE' ... 'vDUgAbwOsQZUpPmBPAAAAAAAAAAIA='),
#                     'dtype': 'f8'}}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'Y'}},
#                              'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'scene': {'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#                          'xaxis': {'title': {'text': 'X1'}},
#                          'yaxis': {'title': {'text': 'X2'}},
#                          'zaxis': {'title': {'text': 'X1*X2'}}},
#                'template': '...'}
# })

# %%
px.scatter_3d(df, x='X1_Square', y='X2_Square', z='X1*X2', color='Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/Documents/Personal/Python/myenv/lib/python3.13/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': ('X1_Square=%{x}<br>X2_Square=%{' ... '%{marker.color}<extra></extra>'),
#               'legendgroup': '',
#               'marker': {'color': {'bdata': ('AAAAAAAAAAAAAAAAAAAAAAAAAAAAAA' ... 'EBAQEBAQEBAQEBAQEBAQEBAQEBAQ=='),
#                                    'dtype': 'i1'},
#                          'coloraxis': 'coloraxis',
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'scene': 'scene',
#               'showlegend': False,
#               'type': 'scatter3d',
#               'x': {'bdata': ('AQAAAADAUkDQrw1U/v9SQBS6zFKuPl' ... '6zlKv/P8Dn1wYq/+8/AAAAAAAAAAA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAAAAOUDAQMmvBgA4QLAXzbRGBT' ... '20RgU3QMJAya8GADhAAAAAAAAAOUA='),
#                     'dtype': 'f8'},
#               'z': {'bdata': ('5vuEBZCmRcA8YDcJrFpFwNB0wAZZDE' ... 'vDUgAbwOsQZUpPmBPAAAAAAAAAAIA='),
#                     'dtype': 'f8'}}],
#     'layout': {'coloraxis': {'colorbar': {'title': {'text': 'Y'}},
#                              'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'scene': {'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#                          'xaxis': {'title': {'text': 'X1_Square'}},
#                          'yaxis': {'title': {'text': 'X2_Square'}},
#                          'zaxis': {'title': {'text': 'X1*X2'}}},
#                'template': '...'}
# })

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier= SVC(kernel='linear')
classifier.fit(X_train, y_train)
y_pred=classifier.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 1.0
