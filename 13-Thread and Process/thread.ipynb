# %% [markdown]
# #### Program: Set of instruction written in a programming language.
# #### Process: Instance of a program that is being executed.
# ####  Thread: Unit of execution inside a process(Each thread has seperate STack and Register)
# MultiThreading :
# 1. I/O bound task: Task that taking more time waiting for I/O operarion.
# 2. Concurrent execution: When want to improve thtroughpiut execution of our application by performing multiple operation concurrently.
#
# MultiProcess :
# Process that run in parallel(Multiple core of the CPU)

# %%
import threading
import time
def print_numbers():
    for i in range(1, 6):
        print(i)
        time.sleep(1)

print_numbers()
# Out:
# 1
# 2
# 3
# 4
# 5
